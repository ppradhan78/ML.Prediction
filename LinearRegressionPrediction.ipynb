# %% [markdown]
# Package Installer

# %%
#

# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
boston = pd.read_csv('boston_house_prices.csv')
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
type(boston)
dataset=boston.head()
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     5 non-null      float64
#  1   ZN       5 non-null      float64
#  2   INDUS    5 non-null      float64
#  3   CHAS     5 non-null      int64
#  4   NOX      5 non-null      float64
#  5   RM       5 non-null      float64
#  6   AGE      5 non-null      float64
#  7   DIS      5 non-null      float64
#  8   RAD      5 non-null      int64
#  9   TAX      5 non-null      int64
#  10  PTRATIO  5 non-null      float64
#  11  B        5 non-null      float64
#  12  LSTAT    5 non-null      float64
#  13  Price    5 non-null      float64
# dtypes: float64(11), int64(3)
# memory usage: 692.0 bytes

# %%
## Summarizing The Stats of the data
dataset.describe()
# Out:
#            CRIM         ZN     INDUS  CHAS       NOX        RM        AGE  \
# count  5.000000   5.000000  5.000000   5.0  5.000000  5.000000   5.000000
# mean   0.032468   3.600000  4.162000   0.0  0.478400  6.865200  61.040000
# std    0.022778   8.049845  2.655159   0.0  0.033768  0.346716  12.402943
# min    0.006320   0.000000  2.180000   0.0  0.458000  6.421000  45.800000
# 25%    0.027290   0.000000  2.180000   0.0  0.458000  6.575000  54.200000
# 50%    0.027310   0.000000  2.310000   0.0  0.469000  6.998000  61.100000
# 75%    0.032370   0.000000  7.070000   0.0  0.469000  7.147000  65.200000
# max    0.069050  18.000000  7.070000   0.0  0.538000  7.185000  78.900000
#
#             DIS      RAD         TAX    PTRATIO           B     LSTAT  \
# count  5.000000  5.00000    5.000000   5.000000    5.000000  5.000000
# mean   5.229720  2.20000  244.800000  17.660000  395.632000  5.284000
# std    0.840081  0.83666   30.318311   1.393915    1.849235  2.346813
# ...

# %%
## Check the missing Values
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
### EXploratory Data Analysis
## Correlation
dataset.corr()
# Out:
#              CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.641718 -0.222977   NaN -0.716845  0.586231 -0.398149
# ZN      -0.641718  1.000000 -0.389920   NaN  0.986647 -0.467895  0.187497
# INDUS   -0.222977 -0.389920  1.000000   NaN -0.234730 -0.175443  0.669335
# CHAS          NaN       NaN       NaN   NaN       NaN       NaN       NaN
# NOX     -0.716845  0.986647 -0.234730   NaN  1.000000 -0.524947  0.316312
# RM       0.586231 -0.467895 -0.175443   NaN -0.524947  1.000000 -0.759995
# AGE     -0.398149  0.187497  0.669335   NaN  0.316312 -0.759995  1.000000
# DIS      0.821613 -0.758406 -0.304475   NaN -0.854438  0.608167 -0.667705
# RAD      0.821614 -0.801784 -0.237681   NaN -0.888413  0.607411 -0.632164
# TAX     -0.775298  0.944039 -0.064373   NaN  0.985155 -0.569900  0.442936
# PTRATIO  0.773251 -0.946456  0.071763   NaN -0.986399  0.568309 -0.437744
# B        0.126399  0.383312 -0.373544   NaN  0.338559 -0.625055  0.374419
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.641718 -0.222977   NaN -0.716845  0.586231 -0.398149
# ZN      -0.641718  1.000000 -0.389920   NaN  0.986647 -0.467895  0.187497
# INDUS   -0.222977 -0.389920  1.000000   NaN -0.234730 -0.175443  0.669335
# CHAS          NaN       NaN       NaN   NaN       NaN       NaN       NaN
# NOX     -0.716845  0.986647 -0.234730   NaN  1.000000 -0.524947  0.316312
# RM       0.586231 -0.467895 -0.175443   NaN -0.524947  1.000000 -0.759995
# AGE     -0.398149  0.187497  0.669335   NaN  0.316312 -0.759995  1.000000
# DIS      0.821613 -0.758406 -0.304475   NaN -0.854438  0.608167 -0.667705
# RAD      0.821614 -0.801784 -0.237681   NaN -0.888413  0.607411 -0.632164
# TAX     -0.775298  0.944039 -0.064373   NaN  0.985155 -0.569900  0.442936
# PTRATIO  0.773251 -0.946456  0.071763   NaN -0.986399  0.568309 -0.437744
# B        0.126399  0.383312 -0.373544   NaN  0.338559 -0.625055  0.374419
# ...

# %%
plt.scatter(dataset['CRIM'],dataset['Price'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['RM'],dataset['Price'])
plt.xlabel("RM")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import seaborn as sns
sns.regplot(x="RM",y="Price",data=dataset)
# Out:
# <Axes: xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x="LSTAT",y="Price",data=dataset)
# Out:
# <Axes: xlabel='LSTAT', ylabel='Price'>

# %%
sns.regplot(x="CHAS",y="Price",data=dataset)
# Out:
# <Axes: xlabel='CHAS', ylabel='Price'>

# %%
sns.regplot(x="PTRATIO",y="Price",data=dataset)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='Price'>

# %%
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
y
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
##Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
#
#         B  LSTAT
# 2  392.83   4.03
# 0  396.90   4.98
# 3  394.63   2.94

# %%
X_test
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 1  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 4  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#        B  LSTAT
# 1  396.9   9.14
# 4  396.9   5.33

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[ 0.46976694, -0.70710678,  1.41382874,  0.        , -0.54605319,
#          1.04114269,  0.44719221, -0.09006941,  0.        , -0.36260608,
#          0.37079182, -1.17499211,  0.05599015],
#        [-1.39008443,  1.41421356, -0.67834477,  0.        ,  1.40279181,
#         -1.34943588,  0.93830508, -1.17722371, -1.22474487,  1.36510523,
#         -1.36729484,  1.26907155,  1.19578956],
#        [ 0.92031749, -0.70710678, -0.73548397,  0.        , -0.85673862,
#          0.30829319, -1.38549728,  1.26729312,  1.22474487, -1.00249915,
#          0.99650302, -0.09407944, -1.25177971]])

# %%
X_test
# Out:
# array([[ 0.47154076, -0.70710678,  1.41382874,  0.        , -0.54605319,
#         -1.952959  ,  2.57934076, -0.09006941,  0.        , -0.36260608,
#          0.37079182,  1.26907155,  6.1869112 ],
#        [ 4.17350531, -0.70710678, -0.73548397,  0.        , -0.85673862,
#          0.8922214 , -0.37931482,  1.26729312,  1.22474487, -1.00249915,
#          0.99650302,  1.26907155,  1.61571566]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
print(regression.coef_)
# Out:
# [ 0.48557493 -0.59704965  0.76956757  0.         -0.52238267  0.73445331
#   0.01587396  0.1918501   0.24172616 -0.4324633   0.43657592 -0.7787731
#  -0.21083708]

# %%
print(regression.intercept_)
# Out:
# 30.7

# %%
## on which parameters the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### Prediction With Test Data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([29.33968253, 33.75834687])

# %%
## plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)

# %%
## Residuals
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 1   -7.739683
# 4    2.441653
# Name: Price, dtype: float64

# %%
## Plot this residuals 

sns.displot(residuals,kind="kde")

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 5.090667833651134
# 32.93217787078669
# 5.738656451712952

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.3820195558118469

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 1.0514983703490128

# %%
boston.values.reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, ..., 3.969e+02, 7.880e+00,
#         1.190e+01]])

# %%
import numpy as np

np.array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
        4.980e+00]])
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
# import numpy as np
##transformation of new data
# scaler.transform(boston.values.reshape(1,-1))
# data=boston.values.reshape(1,-1)
# scaler.transform(boston)

# %%
# regression.predict(scaler.transform(boston.values.reshape(1,-1)))

# %%
import pickle
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
## Prediction
#pickled_model.predict(scaler.transform(boston.values.reshape(1,-1)))
